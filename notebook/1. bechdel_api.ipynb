# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read all movies
# get the full movie list from https://bechdeltest.com/

# %%
df = pd.read_json('http://bechdeltest.com/api/v1/getAllMovies')

# %% [markdown]
# #### look how many film are present

# %%
df.tail()
# Out:
#           id  rating                             title  year    imdbid
# 10131  10995       3  Winnie-the-Pooh: Blood and Honey  2023  19623240
# 10132  10996       3                   Haunted Mansion  2023   1695843
# 10133  11009       3                Portable Door, The  2023  11820950
# 10134  11010       3          Anatomie d&#39;une chute  2023  17009710
# 10135  11015       3                      Slotherhouse  2023  15422224

# %% [markdown]
# #### look at last film on Bechdel dataset from Kaggle

# %%
df_old = pd.read_csv("../data/Bechdel_kaggle.csv")

# %%
df_old
# Out:
#                            title    year  bt_score  dubious      imdbid  \
# 0               Passage de Venus  1874.0       0.0      0.0   3155794.0
# 1              La Rosace Magique  1877.0       0.0      0.0  14495706.0
# 2     Sallie Gardner at a Gallop  1878.0       0.0      0.0   2221420.0
# 3              Le singe musicien  1878.0       0.0      0.0  12592084.0
# 4        Athlete Swinging a Pick  1881.0       0.0      0.0   7816420.0
# ...                          ...     ...       ...      ...         ...
# 9368                   Love Hard  2021.0       2.0      0.0  10752004.0
# 9369                     Cruella  2021.0       3.0      0.0   3228774.0
# 9370             West Side Story  2021.0       3.0      0.0   3581652.0
# 9371     Every Time a Bell Rings  2021.0       3.0      0.0  15943414.0
# 9372          Single All The Way  2021.0       3.0      0.0  14315756.0
#
#            id  submitterid                 date  visible
# 0      9602.0      18880.0  2021-04-02 20:58:09      1.0
# 1      9804.0      19145.0  2021-05-11 00:11:22      1.0
# 2      9603.0      18882.0  2021-04-03 02:25:27      1.0
# 3      9806.0      19151.0  2021-05-11 23:38:54      1.0
# 4      9816.0      19162.0  2021-05-13 01:32:14      1.0
# ...       ...          ...                  ...      ...
# 9368  10152.0      19735.0  2021-12-05 19:22:20      1.0
# 9369   9861.0      19231.0  2021-06-01 03:16:58      1.0
# 9370  10157.0      19743.0  2021-12-10 03:10:09      1.0
# 9371  10158.0      19744.0  2021-12-10 08:03:02      1.0
# 9372  10161.0      19753.0  2021-12-15 10:10:36      1.0
#
# [9373 rows x 9 columns]

# %% [markdown]
# I need to add films between index 9373 and 10135

# %%
df_old["imdbid"].iloc[-1]
# Out:
# 14315756.0

# %% [markdown]
# ## Get movie by imdbid

# %% [markdown]
# Try with one film request

# %%
pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(14315756), typ='series')
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_7632\2789128519.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(14315756), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_7632\2789128519.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(14315756), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_7632\2789128519.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(14315756), typ='series')
# imdbid                    14315756
# title           Single All The Way
# date           2021-12-15 10:10:36
# year                          2021
# submitterid                  19753
# visible                          1
# dubious                          0
# rating                           3
# id                           10161
# dtype: object

# %% [markdown]
# Obtain info for the new film

# %%
c = 9372

# %%
count = 1
# create an empty dataframe
df_new = pd.DataFrame(columns=['title', 'year', 'bt_score', 'dubious', 'imdbid', 'id', 'submitterid', 'date', 'visible'])

# call from the latest to the earliest movie, in case the website crashes
for imdbid in df['imdbid'][-1:c:-1]:
    series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
    #print(series)
    df_new.loc[len(df_new.index)] = series
    ################## df_new = df_new.append(series, ignore_index=True)
    # every 10 movies, we save to a csv file, 
    # so that we wouldn't lose everything when there is an error
    if count % 10 == 0:
        df_new.to_csv('../data/Bechdel_updated.csv')
    count += 1
    
# reverse 
df_new = df_new.iloc[::-1].reset_index(drop=True)

df_new.to_csv('../data/Bechdel_updated.csv',index=False)
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# ...
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19236\2475322188.py:7: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       5 # call from the latest to the earliest movie, in case the website crashes
#       6 for imdbid in df['imdbid'][-1:c:-1]:
# ----> 7     series = pd.read_json('http://bechdeltest.com/api/v1/getMovieByImdbId?imdbid=' + str(imdbid), typ='series')
#       8     #print(series)
#       9     df_new.loc[len(df_new.index)] = series
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\json\_json.py:780, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     777 if convert_axes is None and orient != "table":
#     778     convert_axes = True
# --> 780 json_reader = JsonReader(
#     781     path_or_buf,
#     782     orient=orient,
#     783     typ=typ,
#     784     dtype=dtype,
#     785     convert_axes=convert_axes,
#     786     convert_dates=convert_dates,
#     787     keep_default_dates=keep_default_dates,
#     788     precise_float=precise_float,
#     789     date_unit=date_unit,
#     790     encoding=encoding,
#     791     lines=lines,
#     792     chunksize=chunksize,
#     793     compression=compression,
#     794     nrows=nrows,
#     795     storage_options=storage_options,
#     796     encoding_errors=encoding_errors,
#     797     dtype_backend=dtype_backend,
#     798     engine=engine,
#     799 )
#     801 if chunksize:
#     802     return json_reader
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\json\_json.py:893, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     891     self.data = filepath_or_buffer
#     892 elif self.engine == "ujson":
# --> 893     data = self._get_data_from_filepath(filepath_or_buffer)
#     894     self.data = self._preprocess_data(data)
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\json\_json.py:933, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     926 filepath_or_buffer = stringify_path(filepath_or_buffer)
#     927 if (
#     928     not isinstance(filepath_or_buffer, str)
#     929     or is_url(filepath_or_buffer)
#     930     or is_fsspec_url(filepath_or_buffer)
#     931     or file_exists(filepath_or_buffer)
#     932 ):
# --> 933     self.handles = get_handle(
#     934         filepath_or_buffer,
#     935         "r",
#     936         encoding=self.encoding,
#     937         compression=self.compression,
#     938         storage_options=self.storage_options,
#     939         errors=self.encoding_errors,
#     940     )
#     941     filepath_or_buffer = self.handles.handle
#     942 elif (
#     943     isinstance(filepath_or_buffer, str)
#     944     and filepath_or_buffer.lower().endswith(
#    (...)
#     947     and not file_exists(filepath_or_buffer)
#     948 ):
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~\miniconda3\envs\ironhack\Lib\urllib\request.py:1317, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1314     raise URLError('no host given')
#    1316 # will parse host:port
# -> 1317 h = http_class(host, timeout=req.timeout, **http_conn_args)
#    1318 h.set_debuglevel(self._debuglevel)
#    1320 headers = dict(req.unredirected_hdrs)
#
# File ~\miniconda3\envs\ironhack\Lib\http\client.py:1425, in HTTPSConnection.__init__(self, host, port, key_file, cert_file, timeout, source_address, context, check_hostname, blocksize)
#    1423 self.cert_file = cert_file
#    1424 if context is None:
# -> 1425     context = ssl._create_default_https_context()
#    1426     # send ALPN extension to indicate HTTP/1.1 protocol
#    1427     if self._http_vsn == 11:
#
# File ~\miniconda3\envs\ironhack\Lib\ssl.py:775, in create_default_context(purpose, cafile, capath, cadata)
#     770     context.load_verify_locations(cafile, capath, cadata)
#     771 elif context.verify_mode != CERT_NONE:
#     772     # no explicit cafile, capath or cadata but the verify mode is
#     773     # CERT_OPTIONAL or CERT_REQUIRED. Let's try to load default system
#     774     # root CA certificates for the given purpose. This may fail silently.
# --> 775     context.load_default_certs(purpose)
#     776 # OpenSSL 1.1.1 keylog file
#     777 if hasattr(context, 'keylog_filename'):
#
# File ~\miniconda3\envs\ironhack\Lib\ssl.py:597, in SSLContext.load_default_certs(self, purpose)
#     595     for storename in self._windows_cert_stores:
#     596         self._load_windows_store_certs(storename, purpose)
# --> 597 self.set_default_verify_paths()
#
# KeyboardInterrupt:

# %%
df_new.sample(5)
# Out:
#                            title    year  rating  dubious      imdbid  \
# 619                       Athena  2022.0     2.0      0.0  15445056.0
# 393  America: The Motion Picture  2021.0     3.0      1.0   6733874.0
# 536                    Uncharted  2022.0     2.0      1.0   1464335.0
# 76                         HELEN  2019.0     1.0      0.0  10308528.0
# 89            Vast of Night, The  2019.0     3.0      0.0   6803046.0
#
#           id  submitterid                 date  visible
# 619  10535.0      20489.0  2022-10-14 14:13:54      1.0
# 393   9924.0      19325.0  2021-07-02 21:22:53      1.0
# 536  10226.0      19901.0  2022-02-14 13:05:22      1.0
# 76    9089.0      17887.0  2020-04-22 22:02:01      1.0
# 89    9159.0      18064.0  2020-06-07 01:22:07      1.0

# %% [markdown]
# #### Concatenate the two datasets

# %%
df_new = pd.read_csv("../data/Bechdel_updated.csv")

# %%
df_new
# Out:
#                                 title    year  bt_score  dubious      imdbid  \
# 0                          Gemini Man  2019.0       1.0      0.0   1025100.0
# 1                      Ford v Ferrari  2019.0       0.0      0.0   1950186.0
# 2                            Hustlers  2019.0       3.0      0.0   5503686.0
# 3        Maleficent: Mistress of Evil  2019.0       3.0      0.0   4777008.0
# 4                     Laundromat, The  2019.0       3.0      0.0   5865326.0
# ..                                ...     ...       ...      ...         ...
# 760  Winnie-the-Pooh: Blood and Honey  2023.0       3.0      0.0  19623240.0
# 761                   Haunted Mansion  2023.0       3.0      0.0   1695843.0
# 762                Portable Door, The  2023.0       3.0      0.0  11820950.0
# 763          Anatomie d&#39;une chute  2023.0       3.0      0.0  17009710.0
# 764                      Slotherhouse  2023.0       3.0      0.0  15422224.0
#
#           id  submitterid                 date  visible
# 0     8868.0      17383.0  2019-10-12 10:46:05      1.0
# 1     8869.0      17384.0  2019-10-12 10:48:31      1.0
# 2     8870.0      17389.0  2019-10-14 13:49:26      1.0
# 3     8876.0      17403.0  2019-10-26 22:39:21      1.0
# 4     8877.0      17405.0  2019-10-27 07:11:37      1.0
# ..       ...          ...                  ...      ...
# 760  10995.0      21441.0  2023-09-03 11:21:01      1.0
# 761  10996.0      21442.0  2023-09-03 18:32:34      1.0
# 762  11009.0      21466.0  2023-09-16 03:43:53      1.0
# 763  11010.0      21469.0  2023-09-19 08:14:23      1.0
# 764  11015.0      21477.0  2023-09-24 01:56:22      1.0
#
# [765 rows x 9 columns]

# %%
bechdel_df = pd.concat([df_old,df_new],axis=0)
bechdel_df.rename(columns={"rating":"bt_score"},inplace=True)

# %%
bechdel_df
# Out:
#                                 title    year  bt_score  dubious      imdbid  \
# 0                    Passage de Venus  1874.0       0.0      0.0   3155794.0
# 1                   La Rosace Magique  1877.0       0.0      0.0  14495706.0
# 2          Sallie Gardner at a Gallop  1878.0       0.0      0.0   2221420.0
# 3                   Le singe musicien  1878.0       0.0      0.0  12592084.0
# 4             Athlete Swinging a Pick  1881.0       0.0      0.0   7816420.0
# ..                                ...     ...       ...      ...         ...
# 760  Winnie-the-Pooh: Blood and Honey  2023.0       3.0      0.0  19623240.0
# 761                   Haunted Mansion  2023.0       3.0      0.0   1695843.0
# 762                Portable Door, The  2023.0       3.0      0.0  11820950.0
# 763          Anatomie d&#39;une chute  2023.0       3.0      0.0  17009710.0
# 764                      Slotherhouse  2023.0       3.0      0.0  15422224.0
#
#           id  submitterid                 date  visible
# 0     9602.0      18880.0  2021-04-02 20:58:09      1.0
# 1     9804.0      19145.0  2021-05-11 00:11:22      1.0
# 2     9603.0      18882.0  2021-04-03 02:25:27      1.0
# 3     9806.0      19151.0  2021-05-11 23:38:54      1.0
# 4     9816.0      19162.0  2021-05-13 01:32:14      1.0
# ..       ...          ...                  ...      ...
# 760  10995.0      21441.0  2023-09-03 11:21:01      1.0
# 761  10996.0      21442.0  2023-09-03 18:32:34      1.0
# 762  11009.0      21466.0  2023-09-16 03:43:53      1.0
# 763  11010.0      21469.0  2023-09-19 08:14:23      1.0
# 764  11015.0      21477.0  2023-09-24 01:56:22      1.0
#
# [10138 rows x 9 columns]

# %%
bechdel_df.reset_index(drop=True, inplace=True)

# %%
bechdel_df
# Out:
#                                   title    year  bt_score  dubious  \
# 0                      Passage de Venus  1874.0       0.0      0.0
# 1                     La Rosace Magique  1877.0       0.0      0.0
# 2            Sallie Gardner at a Gallop  1878.0       0.0      0.0
# 3                     Le singe musicien  1878.0       0.0      0.0
# 4               Athlete Swinging a Pick  1881.0       0.0      0.0
# ...                                 ...     ...       ...      ...
# 10133  Winnie-the-Pooh: Blood and Honey  2023.0       3.0      0.0
# 10134                   Haunted Mansion  2023.0       3.0      0.0
# 10135                Portable Door, The  2023.0       3.0      0.0
# 10136          Anatomie d&#39;une chute  2023.0       3.0      0.0
# 10137                      Slotherhouse  2023.0       3.0      0.0
#
#            imdbid       id  submitterid                 date  visible
# 0       3155794.0   9602.0      18880.0  2021-04-02 20:58:09      1.0
# 1      14495706.0   9804.0      19145.0  2021-05-11 00:11:22      1.0
# 2       2221420.0   9603.0      18882.0  2021-04-03 02:25:27      1.0
# 3      12592084.0   9806.0      19151.0  2021-05-11 23:38:54      1.0
# 4       7816420.0   9816.0      19162.0  2021-05-13 01:32:14      1.0
# ...           ...      ...          ...                  ...      ...
# 10133  19623240.0  10995.0      21441.0  2023-09-03 11:21:01      1.0
# 10134   1695843.0  10996.0      21442.0  2023-09-03 18:32:34      1.0
# 10135  11820950.0  11009.0      21466.0  2023-09-16 03:43:53      1.0
# 10136  17009710.0  11010.0      21469.0  2023-09-19 08:14:23      1.0
# 10137  15422224.0  11015.0      21477.0  2023-09-24 01:56:22      1.0
#
# [10138 rows x 9 columns]

# %%
bechdel_df.duplicated().value_counts()
# Out:
# False    9742
# Name: count, dtype: int64

# %%
bechdel_df.drop_duplicates(inplace=True)

# %%
bechdel_df.to_csv('../data/Bechdel.csv',index=False)
